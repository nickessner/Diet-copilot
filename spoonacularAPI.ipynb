# %%
import io
import pandas as pd
import requests
import requests_html
import numpy as np

from pycaret.classification import *
from pycaret.regression import *

import tensorflow as tf

import getpass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12792/1758234408.py in <module>
#       8 from pycaret.regression import *
#       9
# ---> 10 import tensorflow as tf
#      11
#      12 import getpass
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
# import spoonacular as sp
apiKey = getpass.getpass()
# api = sp.API("9de53dbbd57446f8b2d529f97b5d7f70")

# %%
# #Using pypi library
# response = api.generate_meal_plan(diet='vegetarian', exclude=None, targetCalories=2000, timeFrame='Day')
# data = response.json()
# data.keys()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18380/264025460.py in <module>
#       1 # #Using pypi library
# ----> 2 import pypi
#       3 response = api.generate_meal_plan(diet='vegetarian', exclude=None, targetCalories=2000, timeFrame='Day')
#       4 data = response.json()
#       5 data.keys()
#
# ModuleNotFoundError: No module named 'pypi'

# %%
# data['meals']
# data

# %%
#using standard requests setup

#find by nutrients
response = requests.get(f'https://api.spoonacular.com/recipes/findByNutrients?apiKey={apiKey}&minProtein=40&maxProtein=60&maxCalories=600&number=30')

# %%
data = response.json()
data
# Out:
# [{'id': 610952,
#   'title': 'Crispy Buttermilk-herb fried chicken',
#   'image': 'https://spoonacular.com/recipeImages/610952-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 491,
#   'protein': '42g',
#   'fat': '18g',
#   'carbs': '37g'},
#  {'id': 632244,
#   'title': 'Alouette Chicken Paprika',
#   'image': 'https://spoonacular.com/recipeImages/632244-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 461,
#   'protein': '51g',
#   'fat': '25g',
#   'carbs': '6g'},
#  {'id': 632590,
#   'title': 'Apple Roasted Pork Loin',
#   'image': 'https://spoonacular.com/recipeImages/632590-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 512,
#   'protein': '51g',
#   'fat': '17g',
#   'carbs': '37g'},
#  {'id': 634751,
#   'title': 'Beer Braised Brisket with Ding Dang Good Sauce',
#   'image': 'https://spoonacular.com/recipeImages/634751-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 579,
#   'protein': '50g',
#   'fat': '19g',
#   'carbs': '46g'},
#  {'id': 637275,
#   'title': 'Cassoulet for 10',
#   'image': 'https://spoonacular.com/recipeImages/637275-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 591,
#   'protein': '43g',
#   'fat': '24g',
#   'carbs': '40g'},
#  {'id': 637391,
#   'title': 'Chai Pani’s Malabar Chicken Curry',
#   'image': 'https://spoonacular.com/recipeImages/637391-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 544,
#   'protein': '53g',
#   'fat': '26g',
#   'carbs': '19g'},
#  {'id': 637488,
#   'title': 'Chavrie Stuffed Turkey Burgers',
#   'image': 'https://spoonacular.com/recipeImages/637488-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 361,
#   'protein': '45g',
#   'fat': '10g',
#   'carbs': '21g'},
#  {'id': 637670,
#   'title': 'Cheesy Pasta in a Pot',
#   'image': 'https://spoonacular.com/recipeImages/637670-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 491,
#   'protein': '44g',
#   'fat': '20g',
#   'carbs': '29g'},
#  {'id': 638249,
#   'title': 'Chicken Piccata with Artichokes',
#   'image': 'https://spoonacular.com/recipeImages/638249-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 529,
#   'protein': '47g',
#   'fat': '23g',
#   'carbs': '29g'},
#  {'id': 638464,
#   'title': 'Chicken, Red Pepper, and White Bean Chili',
#   'image': 'https://spoonacular.com/recipeImages/638464-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 505,
#   'protein': '44g',
#   'fat': '17g',
#   'carbs': '35g'},
#  {'id': 639567,
#   'title': 'classic beef burgundy',
#   'image': 'https://spoonacular.com/recipeImages/639567-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 490,
#   'protein': '44g',
#   'fat': '16g',
#   'carbs': '28g'},
#  {'id': 640921,
#   'title': 'Stuffed Artichoke Main Dish',
#   'image': 'https://spoonacular.com/recipeImages/640921-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 500,
#   'protein': '56g',
#   'fat': '9g',
#   'carbs': '41g'},
#  {'id': 641973,
#   'title': 'Easy Garlic Roast Leg Of Lamb With Rosemary and Parsley',
#   'image': 'https://spoonacular.com/recipeImages/641973-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 496,
#   'protein': '59g',
#   'fat': '27g',
#   'carbs': '1g'},
#  {'id': 642998,
#   'title': 'Fisherman’s Catch Pasta',
#   'image': 'https://spoonacular.com/recipeImages/642998-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 545,
#   'protein': '42g',
#   'fat': '24g',
#   'carbs': '30g'},
#  {'id': 643016,
#   'title': 'Five Spice & Orange Duck',
#   'image': 'https://spoonacular.com/recipeImages/643016-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 426,
#   'protein': '56g',
#   'fat': '11g',
#   'carbs': '19g'},
#  {'id': 644167,
#   'title': 'Garam Masala Pork Chops with Mint Yogurt and Spiced Couscous',
#   'image': 'https://spoonacular.com/recipeImages/644167-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 461,
#   'protein': '47g',
#   'fat': '15g',
#   'carbs': '29g'},
#  {'id': 644711,
#   'title': 'Gingered Roast Beef',
#   'image': 'https://spoonacular.com/recipeImages/644711-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 533,
#   'protein': '54g',
#   'fat': '15g',
#   'carbs': '33g'},
#  {'id': 650878,
#   'title': 'Maple and Mustard-Glazed Salmon',
#   'image': 'https://spoonacular.com/recipeImages/650878-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 358,
#   'protein': '45g',
#   'fat': '15g',
#   'carbs': '8g'},
#  {'id': 654504,
#   'title': 'Pancit Bihon (Filipino Pancit)',
#   'image': 'https://spoonacular.com/recipeImages/654504-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 572,
#   'protein': '57g',
#   'fat': '17g',
#   'carbs': '41g'},
#  {'id': 659158,
#   'title': 'Salsa Chicken & Black Beans',
#   'image': 'https://spoonacular.com/recipeImages/659158-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 417,
#   'protein': '41g',
#   'fat': '8g',
#   'carbs': '30g'},
#  {'id': 660312,
#   'title': 'Slow-roasted duck legs',
#   'image': 'https://spoonacular.com/recipeImages/660312-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 381,
#   'protein': '46g',
#   'fat': '20g',
#   'carbs': '1g'},
#  {'id': 660490,
#   'title': 'Sockeye Salmon on Kiwi & Lemon Puree',
#   'image': 'https://spoonacular.com/recipeImages/660490-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 433,
#   'protein': '46g',
#   'fat': '22g',
#   'carbs': '10g'},
#  {'id': 667699,
#   'title': 'Slow Cooker Mexican Pulled Pork',
#   'image': 'https://spoonacular.com/recipeImages/667699-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 305,
#   'protein': '46g',
#   'fat': '11g',
#   'carbs': '3g'},
#  {'id': 715384,
#   'title': 'Louisiana Style Gumbo',
#   'image': 'https://spoonacular.com/recipeImages/715384-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 462,
#   'protein': '51g',
#   'fat': '17g',
#   'carbs': '19g'},
#  {'id': 715538,
#   'title': 'What to make for dinner tonight?? Bruschetta Style Pork & Pasta',
#   'image': 'https://spoonacular.com/recipeImages/715538-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 591,
#   'protein': '45g',
#   'fat': '13g',
#   'carbs': '66g'},
#  {'id': 715571,
#   'title': 'Amazing Chicken Pot Pie',
#   'image': 'https://spoonacular.com/recipeImages/715571-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 534,
#   'protein': '42g',
#   'fat': '25g',
#   'carbs': '32g'},
#  {'id': 982375,
#   'title': 'Instant Pot Pressure Cooker Pot Roast',
#   'image': 'https://spoonacular.com/recipeImages/982375-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 484,
#   'protein': '51g',
#   'fat': '9g',
#   'carbs': '42g'},
#  {'id': 1000566,
#   'title': 'Easy Instant Pot Beef Tips and Rice',
#   'image': 'https://spoonacular.com/recipeImages/1000566-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 371,
#   'protein': '53g',
#   'fat': '11g',
#   'carbs': '12g'},
#  {'id': 1095975,
#   'title': 'Best Beef Jerky',
#   'image': 'https://spoonacular.com/recipeImages/1095975-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 422,
#   'protein': '42g',
#   'fat': '14g',
#   'carbs': '31g'},
#  {'id': 1098354,
#   'title': 'Rotisserie Chicken and Bean Tostadas',
#   'image': 'https://spoonacular.com/recipeImages/1098354-312x231.jpg',
#   'imageType': 'jpg',
#   'calories': 558,
#   'protein': '54g',
#   'fat': '23g',
#   'carbs': '29g'}]

# %%
#complex search
response = requests.get(f'https://api.spoonacular.com/recipes/complexSearch?apiKey={apiKey}&diet=ovo-vegetarian&minProtein=30&maxProtein=60&maxCalories=800&number=19')

# %%
data = response.json()
data
# Out:
# {'results': [{'id': 782585,
#    'title': 'Cannellini Bean and Asparagus Salad with Mushrooms',
#    'image': 'https://spoonacular.com/recipeImages/782585-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 482.18,
#       'unit': 'kcal'},
#      {'name': 'Protein', 'amount': 31.0687, 'unit': 'g'}]}},
#   {'id': 766453,
#    'title': "Hummus and Za'atar",
#    'image': 'https://spoonacular.com/recipeImages/766453-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 778.275,
#       'unit': 'kcal'},
#      {'name': 'Protein', 'amount': 33.7542, 'unit': 'g'}]}},
#   {'id': 652706,
#    'title': 'Mushroom Tofu Stew',
#    'image': 'https://spoonacular.com/recipeImages/652706-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 512.525,
#       'unit': 'kcal'},
#      {'name': 'Protein', 'amount': 40.729, 'unit': 'g'}]}},
#   {'id': 795749,
#    'title': 'Crispy Baked Green Bean Fries',
#    'image': 'https://spoonacular.com/recipeImages/795749-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 677.497,
#       'unit': 'kcal'},
#      {'name': 'Protein', 'amount': 31.856, 'unit': 'g'}]}},
#   {'id': 37513,
#    'title': 'Japanese Salad Dressing',
#    'image': 'https://spoonacular.com/recipeImages/37513-312x231.jpg',
#    'imageType': 'jpg',
#    'nutrition': {'nutrients': [{'name': 'Calories',
#       'amount': 738.73,
#       'unit': 'kcal'},
#      {'name': 'Protein', 'amount': 32.4747, 'unit': 'g'}]}}],
#  'offset': 0,
#  'number': 19,
#  'totalResults': 5}

# %%
response = requests.get(f'https://api.spoonacular.com/recipes/652706/information?apiKey={apiKey}&priceBreakdownWidget.json')

#it looks like the leading "information? is important"
#first argument will follow the question mark, next will follow the ampersand"
#https://spoonacular.com/food-api/docs#Authentication

# %%
data = response.json()
data
# Out:
# {'vegetarian': True,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': True,
#  'cheap': False,
#  'veryPopular': False,
#  'sustainable': False,
#  'lowFodmap': False,
#  'weightWatcherSmartPoints': 12,
#  'gaps': 'no',
#  'preparationMinutes': -1,
#  'cookingMinutes': -1,
#  'aggregateLikes': 1,
#  'healthScore': 80,
#  'creditsText': 'Foodista.com – The Cooking Encyclopedia Everyone Can Edit',
#  'license': 'CC BY 3.0',
#  'sourceName': 'Foodista',
#  'pricePerServing': 939.74,
#  'extendedIngredients': [{'id': 14003,
#    'aisle': 'Alcoholic Beverages',
#    'image': 'beer.jpg',
#    'consistency': 'LIQUID',
#    'name': 'bot beer',
#    'nameClean': 'beer',
#    'original': '1 bot beer',
#    'originalName': 'bot beer',
#    'amount': 1.0,
#    'unit': '',
#    'meta': [],
#    'measures': {'us': {'amount': 1.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 1.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 1006615,
#    'aisle': 'Canned and Jarred',
#    'image': 'chicken-broth.png',
#    'consistency': 'LIQUID',
#    'name': 'strong mushroom broth',
#    'nameClean': 'stock',
#    'original': '6 cups Strong mushroom broth, up to 8',
#    'originalName': 'Strong mushroom broth, up to 8',
#    'amount': 6.0,
#    'unit': 'cups',
#    'meta': [],
#    'measures': {'us': {'amount': 6.0, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 1.42, 'unitShort': 'l', 'unitLong': 'liters'}}},
#   {'id': 11124,
#    'aisle': 'Produce',
#    'image': 'sliced-carrot.png',
#    'consistency': 'SOLID',
#    'name': 'carrots',
#    'nameClean': 'carrot',
#    'original': '2 cups Sliced carrots',
#    'originalName': 'Sliced carrots',
#    'amount': 2.0,
#    'unit': 'cups',
#    'meta': ['sliced'],
#    'measures': {'us': {'amount': 2.0, 'unitShort': 'cups', 'unitLong': 'cups'},
#     'metric': {'amount': 473.176,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 16163,
#    'aisle': 'Refrigerated;Produce;Ethnic Foods',
#    'image': 'tofu.png',
#    'consistency': 'SOLID',
#    'name': 'pkt firm/extra tofu',
#    'nameClean': 'extra firm tofu',
#    'original': '1 small pkt Firm/extra firm tofu, (not silken) cut into cubes ½" square',
#    'originalName': 'pkt Firm/extra firm tofu, (not silken) cut into cubes ½" square',
#    'amount': 1.0,
#    'unit': 'small',
#    'meta': ['firm', 'cut into cubes ½" square', '(not silken)'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'small',
#      'unitLong': 'small'},
#     'metric': {'amount': 1.0, 'unitShort': 'small', 'unitLong': 'small'}}},
#   {'id': 11215,
#    'aisle': 'Produce',
#    'image': 'garlic.png',
#    'consistency': 'SOLID',
#    'name': 'garlic',
#    'nameClean': 'garlic',
#    'original': '2 Cloves crushed garlic',
#    'originalName': 'crushed garlic',
#    'amount': 2.0,
#    'unit': 'Cloves',
#    'meta': ['crushed'],
#    'measures': {'us': {'amount': 2.0,
#      'unitShort': 'Cloves',
#      'unitLong': 'Cloves'},
#     'metric': {'amount': 2.0, 'unitShort': 'Cloves', 'unitLong': 'Cloves'}}},
#   {'id': 11260,
#    'aisle': 'Produce',
#    'image': 'mushrooms-white.jpg',
#    'consistency': 'SOLID',
#    'name': 'mushrooms',
#    'nameClean': 'fresh mushrooms',
#    'original': '1/2 pound Mushrooms sliced',
#    'originalName': 'Mushrooms sliced',
#    'amount': 0.5,
#    'unit': 'pound',
#    'meta': ['sliced'],
#    'measures': {'us': {'amount': 0.5, 'unitShort': 'lb', 'unitLong': 'pounds'},
#     'metric': {'amount': 226.796, 'unitShort': 'g', 'unitLong': 'grams'}}},
#   {'id': 11282,
#    'aisle': 'Produce',
#    'image': 'brown-onion.png',
#    'consistency': 'SOLID',
#    'name': 'onion',
#    'nameClean': 'onion',
#    'original': '1 large Onion diced',
#    'originalName': 'Onion diced',
#    'amount': 1.0,
#    'unit': 'large',
#    'meta': ['diced'],
#    'measures': {'us': {'amount': 1.0,
#      'unitShort': 'large',
#      'unitLong': 'large'},
#     'metric': {'amount': 1.0, 'unitShort': 'large', 'unitLong': 'large'}}}],
#  'id': 652706,
#  'title': 'Mushroom Tofu Stew',
#  'readyInMinutes': 45,
#  'servings': 1,
#  'sourceUrl': 'http://www.foodista.com/recipe/TKTPMBJF/mushroom-tofu-stew',
#  'image': 'https://spoonacular.com/recipeImages/652706-556x370.jpg',
#  'imageType': 'jpg',
#  'summary': 'Mushroom Tofu Stew is a <b>gluten free, dairy free, and lacto ovo vegetarian</b> recipe with 1 servings. This main course has <b>513 calories</b>, <b>41g of protein</b>, and <b>9g of fat</b> per serving. For <b>$9.4 per serving</b>, this recipe <b>covers 42%</b> of your daily requirements of vitamins and minerals. It is perfect for <b>Autumn</b>. It is brought to you by Foodista. This recipe is liked by 1 foodies and cooks. Head to the store and pick up garlic, strong mushroom broth, carrots, and a few other things to make it today. From preparation to the plate, this recipe takes approximately <b>45 minutes</b>. Taking all factors into account, this recipe <b>earns a spoonacular score of 88%</b>, which is tremendous. Users who liked this recipe also liked <a href="https://spoonacular.com/recipes/spicy-tofu-stew-757852">Spicy Tofu Stew</a>, <a href="https://spoonacular.com/recipes/tofu-and-kimchi-stew-1582953">Tofu and Kimchi Stew</a>, and <a href="https://spoonacular.com/recipes/tofu-and-kimchi-stew-998341">Tofu and Kimchi Stew</a>.',
#  'cuisines': [],
#  'dishTypes': ['lunch', 'soup', 'main course', 'main dish', 'dinner'],
#  'diets': ['gluten free', 'dairy free', 'lacto ovo vegetarian'],
#  'occasions': ['fall', 'winter'],
#  'winePairing': {'pairedWines': ['cabernet sauvignon', 'chablis', 'malbec'],
#   'pairingText': 'Cabernet Sauvignon, Chablis, and Malbec are my top picks for Stew. Full-bodied red wines like malbec and cabernet sauvignon are the perfect accompaniment for beef stew. Fish stew probably calls for a white wine, such as chablis. The Perez Cruz Pircas de Liguai Single Collection Cabernet Sauvignon with a 4.6 out of 5 star rating seems like a good match. It costs about 45 dollars per bottle.',
#   'productMatches': [{'id': 500272,
#     'title': 'Perez Cruz Pircas de Liguai Single Collection Cabernet Sauvignon',
#     'description': 'The Pircas de Liguai Single Collection Cabernet Sauvignon has a predominantly fruity character and intensity with spiciness, freshness and elegance. Ripe red fruit, black pepper and classic herbal qualities ensure the wine is complex and continues to develop in the glass. Full bodied but always fresh on the palate with well-rounded tannins and a nice grip.',
#     'price': '$44.99',
#     'imageUrl': 'https://spoonacular.com/productImages/500272-312x231.jpg',
#     'averageRating': 0.9199999999999999,
#     'ratingCount': 5.0,
#     'score': 0.8574999999999999,
#     'link': 'https://click.linksynergy.com/deeplink?id=*QCiIS6t4gA&mid=2025&murl=https%3A%2F%2Fwww.wine.com%2Fproduct%2Fperez-cruz-pircas-de-liguai-single-collection-cabernet-sauvignon-2014%2F514979'}]},
#  'instructions': "<ol><li>I just made this up the other day and it was pretty good. The real key is to use a very strong mushroom broth (either make your own or use twice the amount called for with the instant), and to brown all the ingredients first.</li><li>In a large stewpot on med-hi heat, saute onions in beer until very brown and beginning to stick to pot bottom Add just enough mushroom broth to loosen the onions on the bottom of the pan and continue browning. Keep up this process until onions are very dark brown.</li><li>At the same time, in a large skillet, pour 1/4 cup mushroom broth and add cubed tofu. Brown on all sides as much as possible on med-hi, adding broth when tofu starts to stick, loosening the tofu cubes and cooking until they start to stick again. When tofu cubes are browned well, add to onions and add rest of mushroom broth. If more liquid is needed, add water to cover stew if more liquid is needed.</li><li>In same skillet, using water, use same process on carrots and mushrooms, browning and loosening with water and then add to the stew mixture.</li><li>Finally, add crushed garlic, cover and simmer until full flavor has developed.</li><li>This process of browning really increases the flavor of all the contents including the tofu. Don't be afraid to make plenty, as this disappeared fast and there were not enough leftovers for my taste!</li></ol>",
#  'analyzedInstructions': [{'name': '',
#    'steps': [{'number': 1,
#      'step': 'I just made this up the other day and it was pretty good. The real key is to use a very strong mushroom broth (either make your own or use twice the amount called for with the instant), and to brown all the ingredients first.In a large stewpot on med-hi heat, saute onions in beer until very brown and beginning to stick to pot bottom',
#      'ingredients': [{'id': 11260,
#        'name': 'mushrooms',
#        'localizedName': 'mushrooms',
#        'image': 'mushrooms.png'},
#       {'id': 11282,
#        'name': 'onion',
#        'localizedName': 'onion',
#        'image': 'brown-onion.png'},
#       {'id': 1006615,
#        'name': 'broth',
#        'localizedName': 'broth',
#        'image': 'chicken-broth.png'},
#       {'id': 14003,
#        'name': 'beer',
#        'localizedName': 'beer',
#        'image': 'beer.jpg'}],
#      'equipment': [{'id': 404752,
#        'name': 'pot',
#        'localizedName': 'pot',
#        'image': 'stock-pot.jpg'}]},
#     {'number': 2,
#      'step': "Add just enough mushroom broth to loosen the onions on the bottom of the pan and continue browning. Keep up this process until onions are very dark brown.At the same time, in a large skillet, pour 1/4 cup mushroom broth and add cubed tofu. Brown on all sides as much as possible on med-hi, adding broth when tofu starts to stick, loosening the tofu cubes and cooking until they start to stick again. When tofu cubes are browned well, add to onions and add rest of mushroom broth. If more liquid is needed, add water to cover stew if more liquid is needed.In same skillet, using water, use same process on carrots and mushrooms, browning and loosening with water and then add to the stew mixture.Finally, add crushed garlic, cover and simmer until full flavor has developed.This process of browning really increases the flavor of all the contents including the tofu. Don't be afraid to make plenty, as this disappeared fast and there were not enough leftovers for my taste!",
#      'ingredients': [{'id': 11260,
#        'name': 'mushrooms',
#        'localizedName': 'mushrooms',
#        'image': 'mushrooms.png'},
#       {'id': 11124,
#        'name': 'carrot',
#        'localizedName': 'carrot',
#        'image': 'sliced-carrot.png'},
#       {'id': 11215,
#        'name': 'garlic',
#        'localizedName': 'garlic',
#        'image': 'garlic.png'},
#       {'id': 11282,
#        'name': 'onion',
#        'localizedName': 'onion',
#        'image': 'brown-onion.png'},
#       {'id': 1006615,
#        'name': 'broth',
#        'localizedName': 'broth',
#        'image': 'chicken-broth.png'},
#       {'id': 14412,
#        'name': 'water',
#        'localizedName': 'water',
#        'image': 'water.png'},
#       {'id': 0, 'name': 'stew', 'localizedName': 'stew', 'image': ''},
#       {'id': 16213,
#        'name': 'tofu',
#        'localizedName': 'tofu',
#        'image': 'tofu.png'}],
#      'equipment': [{'id': 404645,
#        'name': 'frying pan',
#        'localizedName': 'frying pan',
#        'image': 'pan.png'}]}]}],
#  'originalId': None,
#  'spoonacularSourceUrl': 'https://spoonacular.com/mushroom-tofu-stew-652706'}

# %%
#supposed to be the SDK setup offered for python by spoonacular but cant get it working

# from __future__ import print_function
# import time
# import spoonacular
# from spoonacular.rest import ApiException
# from pprint import pprint

# configuration = spoonacular.Configuration()
# # Configure API key authorization: apiKeyScheme
# configuration.api_key['apiKey'] = apiKey
# # Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
# # configuration.api_key_prefix['apiKey'] = 'Bearer'

# # create an instance of the API class
# api_instance = spoonacular.IngredientsApi(spoonacular.ApiClient(configuration))
# query = 'burger' # str | The (natural language) search query. (optional)
# number = 10 # int | The maximum number of items to return (between 1 and 100). Defaults to 10. (optional) (default to 10)
# meta_information = false # bool | Whether to return more meta information about the ingredients. (optional)
# intolerances = 'egg' # str | A comma-separated list of intolerances. All recipes returned must not contain ingredients that are not suitable for people with the intolerances entered. See a full list of supported intolerances. (optional)

# try:
#     # Autocomplete Ingredient Search
#     api_response = api_instance.autocomplete_ingredient_search(query=query, number=number, meta_information=meta_information, intolerances=intolerances)
#     print(api_response)
# # except ApiException as e:
# except:
#     # print("Exception when calling IngredientsApi->autocomplete_ingredient_search: %s\n" % e)
#     print("Exception when calling IngredientsApi->autocomplete_ingredient_search: %s\n")
